# %% [markdown]
# La misión de hoy es conseguir el calendario de eventos en formato JSON para poder aprovecharlo desde otras aplicaciones.

# %%
LLANES_CAL = "http://llanes.es/calendario"

# %% [markdown]
# Esta es la dirección web del calendario de eventos de Llanes, cargamos el contenido de la web de eventos, que por suerte o por desgracia los trae todos "escondidos".

# %%
from urllib2 import urlopen
calweb = urlopen(LLANES_CAL)
calwebtext1 = calweb.read()

# %%
calwebtext2 = unicode(calwebtext1.decode("utf8"))

# %% [markdown]
# Parseamos el HTML para manejar directamente el DOM, ya que tratar el HTML como texto es una locura.

# %%
from lxml import etree
from io import StringIO, BytesIO
parser = etree.HTMLParser()
doc = etree.parse(StringIO(calwebtext2), parser)

# %% [markdown]
# Los eventos que nos interesan tienen la clase HTML "fullcalendar-event". Los recuperamos usando XPATH.

# %%
events = doc.xpath("//*[@class='fullcalendar-event']")

# %% [markdown]
# Ejemplo de los datos de un evento:

# %%
dict(events[12].xpath(".//a")[0].items())
# Out:
# {'allday': '1',
#  'class': 'fullcalendar-event-details',
#  'cn': 'fc-event-default agenda fc-event-field-field-fechaagenda',
#  'editable': '',
#  'eid': '461',
#  'end': '2012-06-16 00:00:00',
#  'entity_type': 'node',
#  'field': 'field_fechaagenda',
#  'href': '/agenda/san-antonio-piedra',
#  'index': '0',
#  'start': '2012-06-16 00:00:00',
#  'title': 'San Antonio (Piedra)'}

# %% [markdown]
# Creamos una clase para abstraer la extración de los datos desde el DOM de cada evento de la página web

# %%
from datetime import datetime

class Event:
    node = None
    def __init__(self, element):
        self.node = element
    def title(self):
        return self.node.xpath("./h3/text()")[0]
    def attrs(self):
        return dict(self.node.xpath(".//a")[0].items())
    def start(self):
        return datetime.strptime(self.attrs()["start"], "%Y-%m-%d %H:%M:%S")
    def end(self):
        return datetime.strptime(self.attrs()["end"], "%Y-%m-%d %H:%M:%S")
    def allday(self):
        return self.attrs()["allday"] == "1"

# %%
events_objects = [Event(i) for i in events]
print events_objects[12].attrs()
print events_objects[12].end()
print events_objects[12].allday()
# Out:
# {'index': '0', 'allday': '1', 'end': '2012-06-16 00:00:00', 'cn': 'fc-event-default agenda fc-event-field-field-fechaagenda', 'field': 'field_fechaagenda', 'entity_type': 'node', 'editable': '', 'start': '2012-06-16 00:00:00', 'href': '/agenda/san-antonio-piedra', 'eid': '461', 'title': 'San Antonio (Piedra)', 'class': 'fullcalendar-event-details'}
# 2012-06-16 00:00:00
# True

# %% [markdown]
# Extraemos las propiedades que nos interesan y lo volcamos a json.

# %%
def json_event(event_object):
    return {"title": event_object.title(), 
            "start": event_object.start(), 
            "end": event_object.end(), 
            "allday": event_object.allday()
           }

# %% [markdown]
# Hay que tener en cuenta que la librería de JSON no nos define una serialización para las fechas, tenemos que crear una nueva función, usamos el formato ISO por conveniencia.

# %%
import json

def json_date_serializer(obj):
    if isinstance(obj, datetime):
        serial = obj.isoformat()
        return serial
    raise TypeError ("Type not serializable")

json_file = open("calendario_llanes.json", "w")
json_file.write(json.dumps([json_event(i) for i in events_objects], default = json_date_serializer))
json_file.close()

# %% [markdown]
# Ahora vamos a "masajear" un poco los datos para colocar el json con la estructura que más nos conviene para las pruebas, que es una jerarquía:
# * Año
#     * Mes
#         * Dia
#             * Evento
#
# También necesitamos que los eventos aparezcan todos los días desde que empiezan hasta que terminan.
#
# Para ello vamos a generar unas "claves" para cada evento, cada "clave" es una fecha y un evento tiene tantas claves como dias desde que empieza hasta que termina.
#
# En la practica, además de generar cada clave, vamos a adjuntarle el propio evento, haciendo en efecto una *multiplicación de conjuntos* entre los eventos y las claves/fecha.

# %%
from datetime import timedelta
from itertools import chain

'''Descripcion de la transformacion:

{e in Events} =(map-on-keys)=> [(KEY, e)] =(group-by(KEY))=> {KEY -> [e]} 

'''

def map_on_keys(event):
    ''' e in Events -> [(KEY, e)] '''
    start = event.start()
    end = event.end()
    days = [start + timedelta(d) for d in range((end - start).days + 1)] # +1 para que incluya el dia actual si start == end
    return [(d, event) for d in days]

nested = [map_on_keys(e) for e in events_objects]

flatten = list(chain.from_iterable(nested))
# ordenamos in-place por la clave, para luego agrupar, no es necesario pero podria ser eficiente
flatten.sort()

grouped = {}
for key, event in flatten:
    grouped.setdefault(key, [])
    grouped[key].append(event)

print grouped
# Out:
# {'2015-11-19': [<__main__.Event instance at 0x06331968>, <__main__.Event instance at 0x063369E0>], '2015-11-18': [<__main__.Event instance at 0x06331968>, <__main__.Event instance at 0x063369E0>], '2015-11-11': [<__main__.Event instance at 0x06331968>], '2015-11-10': [<__main__.Event instance at 0x06331968>], '2015-11-13': [<__main__.Event instance at 0x06331968>, <__main__.Event instance at 0x063369E0>], '2015-11-12': [<__main__.Event instance at 0x06331968>], '2015-11-15': [<__main__.Event instance at 0x06331968>, <__main__.Event instance at 0x063369E0>], '2015-11-14': [<__main__.Event instance at 0x06331968>, <__main__.Event instance at 0x063369E0>, <__main__.Event instance at 0x06336B98>, <__main__.Event instance at 0x06336BC0>, <__main__.Event instance at 0x06336BE8>], '2015-11-17': [<__main__.Event instance at 0x06331968>, <__main__.Event instance at 0x063369E0>], '2015-11-16': [<__main__.Event instance at 0x06331968>, <__main__.Event instance at 0x063369E0>], '2015-12-14': [<__main__.Event instance at 0x06331968>, <__main__.Event instance at 0x063369E0>, <__main__.Event instance at 0x06336DF0>], '2015-12-15': [<__main__.Event instance at 0x06331968>, <__main__.Event instance at 0x063369E0>, <__main__.Event instance at 0x06336DF0>], '2013-01-03': [<__main__.Event instance at 0x06311698>], '2015-12-17': [<__main__.Event instance at 0x06331968>, <__main__.Event instance at 0x063369E0>, <__main__.Event instance at 0x06336DF0>], '2015-12-10': [<__main__.Event instance at 0x06331968>, <__main__.Event instance at 0x063369E0>, <__main__.Event instance at 0x06336DF0>], '2013-01-04': [<__main__.Event instance at 0x063116C0>], '2015-12-12': [<__main__.Event instance at 0x06331968>, <__main__.Event instance at 0x063369E0>, <__main__.Event instance at 0x06336AA8>, <__main__.Event instance at 0x06336DF0>], '2015-12-13': [<__main__.Event instance at 0x0631A4E0>, <__main__.Event instance at 0x06331968>, <__main__.Event instance at 0x063369E0>, <__main__.Event instance at 0x06336DF0>], '2015-12-18': [<__main__.Event instance at 0x06331968>, <__main__.Event instance at 0x063369E0>, <__main__.Event instance at 0x06336DF0>, <__main__.Event instance at 0x06345030>], '2015-12-19': [<__main__.Event instance at 0x06331968>, <__main__.Event instance at 0x063369E0>, <__main__.Event instance at 0x06336DF0>, <__main__.Event instance at 0x06336EE0>, <__main__.Event instance at 0x06336F08>, <__main__.Event instance at 0x06336F30>, <__main__.Event instance at 0x06336FA8>, <__main__.Event instance at 0x06345030>, <__main__.Event instance at 0x063451C0>], '2014-03-31': [<__main__.Event instance at 0x0631ADF0>], '2014-03-30': [<__main__.Event instance at 0x0631ADF0>, <__main__.Event instance at 0x0631AE18>], '2012-03-19': [<__main__.Event instance at 0x0630EB98>], '2012-03-18': [<__main__.Event instance at 0x0630EB98>], '2016-09-08': [<__main__.Event instance at 0x0630E4B8>, <__main__.Event instance at 0x0630E4E0>, <__main__.Event instance at 0x0630E828>], '2016-09-09': [<__main__.Event instance at 0x0630E508>], '2016-09-04': [<__main__.Event instance at 0x0630E490>], '2012-03-10': [<__main__.Event instance at 0x0630EB70>, <__main__.Event instance at 0x0630EBC0>], '2016-09-07': [<__main__.Event instance at 0x0630E4B8>, <__main__.Event instance at 0x0630E4E0>, <__main__.Event instance at 0x0630E828>], '2016-09-01': [<__main__.Event instance at 0x0630E468>], '2012-03-17': [<__main__.Event instance at 0x0630EB98>], '2012-03-16': [<__main__.Event instance at 0x0630EB98>], '2016-05-31': [<__main__.Event instance at 0x06349198>, <__main__.Event instance at 0x063491C0>], '2016-05-30': [<__main__.Event instance at 0x06301A30>, <__main__.Event instance at 0x06349198>, <__main__.Event instance at 0x063491C0>], '2014-08-09': [<__main__.Event instance at 0x0631FDC8>, <__main__.Event instance at 0x06324080>, <__main__.Event instance at 0x063240A8>, <__main__.Event instance at 0x063240F8>, <__main__.Event instance at 0x06324148>, <__main__.Event instance at 0x0632421 ...

# %%
hierarchy = {}
for key, event in grouped:
    start = e.start()
    y = start.year
    m = start.month
    d = start.day
    
    hierarchy.setdefault(y, {})
    hierarchy[y].setdefault(m, {})
    hierarchy[y][m].setdefault(d, [])
    
    hierarchy[y][m][d].append(json_event(e))

print hierarchy
# Out:
# {2016: {1: {2: [{'start': datetime.datetime(2016, 1, 2, 19, 45), 'allday': False, 'end': datetime.datetime(2016, 1, 2, 19, 45), 'title': u'Concierto de A\xf1o Nuevo del "Coro Concejo de Llanes" en Nueva'}, {'start': datetime.datetime(2016, 1, 2, 13, 0), 'allday': False, 'end': datetime.datetime(2016, 1, 2, 13, 0), 'title': u'Representaci\xf3n de teatro costumbrista "Selecci\xf3n de sainetes asturianos" en Llanes'}], 3: [{'start': datetime.datetime(2016, 1, 3, 20, 0), 'allday': False, 'end': datetime.datetime(2016, 1, 3, 20, 0), 'title': u'Concierto de "Albert Nuijten" (guitarra cl\xe1sica) en Llanes'}, {'start': datetime.datetime(2016, 1, 3, 12, 0), 'allday': False, 'end': datetime.datetime(2016, 1, 3, 12, 0), 'title': u'Cuenta cuentos teatralizado "Color\xedn colorado" en Llanes'}, {'start': datetime.datetime(2016, 1, 3, 0, 0), 'allday': True, 'end': datetime.datetime(2016, 1, 3, 0, 0), 'title': 'Fiesta Solidaria "Ayuda a los Refugiados"'}], 4: [{'start': datetime.datetime(2016, 1, 4, 12, 0), 'allday': False, 'end': datetime.datetime(2016, 1, 4, 12, 0), 'title': 'Taller en familia "Trasgu, el viajero del tiempo"'}], 5: [{'start': datetime.datetime(2016, 1, 5, 19, 0), 'allday': False, 'end': datetime.datetime(2016, 1, 5, 19, 0), 'title': 'Cabalgata de SS. MM. los Reyes Magos en Llanes'}, {'start': datetime.datetime(2016, 1, 5, 12, 30), 'allday': False, 'end': datetime.datetime(2016, 1, 5, 12, 30), 'title': u'Espect\xe1culo de magia de "Sergio Kab" en Llanes'}, {'start': datetime.datetime(2016, 1, 5, 20, 30), 'allday': False, 'end': datetime.datetime(2016, 1, 5, 20, 30), 'title': u'Bel\xe9n Viviente en Cue'}, {'start': datetime.datetime(2016, 1, 5, 19, 30), 'allday': False, 'end': datetime.datetime(2016, 1, 5, 19, 30), 'title': 'Cabalgata de SS. MM. los Reyes Magos en Posada'}, {'start': datetime.datetime(2016, 1, 5, 19, 30), 'allday': False, 'end': datetime.datetime(2016, 1, 5, 19, 30), 'title': 'Cabalgata de SS. MM. los Reyes Magos en Nueva'}], 8: [{'start': datetime.datetime(2016, 1, 8, 0, 0), 'allday': True, 'end': datetime.datetime(2016, 2, 4, 0, 0), 'title': u'Exposici\xf3n "Cr\xedas que pintan muchu II"'}], 9: [{'start': datetime.datetime(2016, 1, 9, 0, 0), 'allday': True, 'end': datetime.datetime(2016, 1, 9, 0, 0), 'title': u'San Julian y Santa Basilisa (Porr\xfaa)'}, {'start': datetime.datetime(2016, 1, 9, 19, 0), 'allday': False, 'end': datetime.datetime(2016, 1, 9, 19, 0), 'title': u'Tertulias en Llanes: "La corrupci\xf3n en Asturias". '}, {'start': datetime.datetime(2016, 1, 9, 18, 0), 'allday': False, 'end': datetime.datetime(2016, 1, 9, 18, 0), 'title': 'Winter Music Party Vol. II'}], 15: [{'start': datetime.datetime(2016, 1, 15, 0, 0), 'allday': True, 'end': datetime.datetime(2016, 1, 15, 0, 0), 'title': 'Espacio Joven Llanes'}], 16: [{'start': datetime.datetime(2016, 1, 16, 0, 0), 'allday': True, 'end': datetime.datetime(2016, 1, 16, 0, 0), 'title': 'Ntra. Sra. de la Paz (Bricia)'}, {'start': datetime.datetime(2016, 1, 16, 0, 0), 'allday': True, 'end': datetime.datetime(2016, 1, 17, 0, 0), 'title': u'San Ant\xf3n (Parres)'}], 23: [{'start': datetime.datetime(2016, 1, 23, 19, 0), 'allday': False, 'end': datetime.datetime(2016, 1, 23, 19, 0), 'title': u'Tertulias en Llanes "Aconfesionalidad, Estado y Religi\xf3n"'}], 27: [{'start': datetime.datetime(2016, 1, 27, 18, 0), 'allday': False, 'end': datetime.datetime(2016, 1, 27, 18, 0), 'title': 'Taller de Tai Chi'}, {'start': datetime.datetime(2016, 1, 27, 9, 0), 'allday': False, 'end': datetime.datetime(2016, 1, 27, 9, 0), 'title': u'"Caf\xe9 de trabajo" en el Centro de Empresas Municipal'}], 30: [{'start': datetime.datetime(2016, 1, 30, 17, 0), 'allday': False, 'end': datetime.datetime(2016, 1, 30, 17, 0), 'title': u'Taller para ni\xf1os "Crea tu juguete" organizado por Cruz Roja'}]}, 2: {5: [{'start': datetime.datetime(2016, 2, 5, 0, 0), 'allday': True, 'end': datetime.datetime(2016, 2, 20, 0, 0), 'title': u'Exposici\xf3n Fotogr\xe1fica "Asturias, naturalmente"'},  ...
